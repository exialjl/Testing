# %%
import pandas as pd

pd.read_csv("BS.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-04ce4df07b99> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv("BS.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\lijia.DESKTOP-GBRD99U'

# %%
cd PycharmProjects\BF3210
# Out:
# C:\Users\lijia.DESKTOP-GBRD99U\PycharmProjects\BF3210

# %%
pwd
# Out:
# 'C:\\Users\\lijia.DESKTOP-GBRD99U\\PycharmProjects\\BF3210'

# %%
import pandas as pd

pd.read_csv("BS.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-04ce4df07b99> in <module>
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv("BS.csv")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pwd
# Out:
# 'C:\\Users\\lijia.DESKTOP-GBRD99U'

# %%
cd \PycharmProjects\BF3210
# Out:
# [WinError 3] The system cannot find the path specified: '\\PycharmProjects\\BF3210'
# C:\Users\lijia.DESKTOP-GBRD99U

# %%
cd PycharmProjects\BF3210
# Out:
# C:\Users\lijia.DESKTOP-GBRD99U\PycharmProjects\BF3210

# %%
import pandas as pd

pd.read_csv("BS.csv")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cash And Equivalents</td>
#       <td>5,459.10</td>
#       <td>5,616.20</td>
#       <td>1,734.60</td>
#       <td>1,874.10</td>
#       <td>2,106.10</td>
#       <td>1,971.80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Short Term Investments</td>
#       <td>363.4</td>
#       <td>261.1</td>
#       <td>125.6</td>
#       <td>126.9</td>
#       <td>55</td>
#       <td>136.6</td>
# ...

# %%
pip install flask
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install flask
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/
